# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# URL of page to be scraped
url = 'https://www.beeradvocate.com/beer/'

# %%
# Retrieve page with the requests module
response = requests.get(url)

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Examine the results, then determine element that contains sought info
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="Public NoJs uix_javascriptNeedsInit LoggedOut Sidebar Responsive pageIsLtr not_hasTabLinks hasSearch is-sidebarOpen hasRightSidebar is-setWidth navStyle_0 pageStyle_0 hasFlexbox" dir="LTR" id="XenForo" lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <base href="https://www.beeradvocate.com/community/"/>
#   <script>
#    var _b = document.getElementsByTagName('base')[0], _bH = "https://www.beeradvocate.com/community/";
# 			if (_b && _b.href != _bH) _b.href = _bH;
#   </script>
#   <title>
#    Beer Reviews: Most Recent | BeerAdvocate
#   </title>
#   <noscript>
#    <style>
#     .JsOnly, .jsOnly { display: none !important; }
#    </style>
#   </noscript>
# ...

# %%
# results are returned as an iterable list
#results = soup.find_all(['span', 'h6'])
#results

results = soup.find_all('h6')
titles = [i.text for i in results]
titles
# Out:
# ['420 Strain G13 IPA',
#  'Dinner',
#  'Alpenflo',
#  'Gooseberry Gose',
#  'German Style Wheat',
#  'Permutation Series #72: Pale Lager',
#  'Pulp Daddy',
#  'Bourbon County Brand Midnight Orange Stout',
#  'German Pilsner',
#  '#CarlBock',
#  'Just Tapped - Baltic Porter',
#  'Moment Of Clarity',
#  'Somewhere, Something Incredible Is Waiting To Be Known - Marshmallow',
#  'Zephyr',
#  'Corkonian',
#  'Bears Hump Nut Brown',
#  'The Prophet',
#  'Lazy Hazer IPA',
#  'Fruit Cobbler',
#  'Pogo',
#  'Blacksmith India Black Ale',
#  'Strawberry Rhubarb',
#  'Revolver Blood And Honey',
#  'Augustiner Bräu Maximator',
#  'River Buddy Pale Ale',
#  'J.R.E.A.M. - Strawberry Rhubarb Pie',
#  'Weihenstephaner Hefeweissbier',
#  'Barracks Brown',
#  'Kuhnhenn Weiss Teufel (White Devil)',
#  'Mirror Universe Hazy IPA',
#  'National Park Hefeweizen',
#  'Death By Coconut',
#  'Triple Shot - Batch 1000',
#  'Almost Relevant',
#  '3 Citrus Peel Out',
#  'Hoponius On Holiday',
# ...

# %%
# # Loop through returned results
# for result in results:
#     # Error handling
#     try:
#         # Identify and return title of listing
#         title = result.find('a').text
#         # Identify and return price of listing
#         rating = result.find(class_="BAscoernorm").text
#         # Identify and return link to listing
#         link = result.a['href']

#         # Print results only if title, price, and link are available
#         if (title and rating and link):
#             print('-------------')
#             print(title)
#             print(rating)
#             print(link)
#     except AttributeError as e:
#         print(e)

results1 = soup.find_all("span",class_ ="BAscore_norm")
rating = [i.text for i in results1]
rating
# Out:
# ['4.28',
#  '4.16',
#  '3.9',
#  '4.1',
#  '3.5',
#  '4.02',
#  '4.35',
#  '4.5',
#  '3.75',
#  '3.75',
#  '4.53',
#  '4.85',
#  '4.93',
#  '3.94',
#  '3.67',
#  '4.02',
#  '3.49',
#  '3.79',
#  '3.75',
#  '4.67',
#  '3.94',
#  '4.59',
#  '3',
#  '4.19',
#  '4.02',
#  '4.25',
#  '4.57',
#  '4.09',
#  '4.11',
#  '3.43',
#  '4.13',
#  '3.88',
#  '4.94',
#  '3.96',
#  '3.78',
#  '4.05',
#  '4.04',
#  '4.13',
#  '4.5',
#  '4.18',
#  '4.07',
#  '4.12',
#  '4.29',
#  '4.09',
#  '4.27',
#  '2.96',
#  '4.49',
#  '4.12',
#  '4.31',
#  '3.87']

# %%
beeradv_df= pd.DataFrame({"Name" : titles, "Score" : rating})

beeradv_df.head()
# Out:
#                  Name Score
# 0  420 Strain G13 IPA  4.28
# 1              Dinner  4.16
# 2            Alpenflo   3.9
# 3     Gooseberry Gose   4.1
# 4  German Style Wheat   3.5
